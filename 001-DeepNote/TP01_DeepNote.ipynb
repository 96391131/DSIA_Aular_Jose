# %% [markdown]
# # TP01 \- Deepnote Aular Jose

# %% [markdown]
# Mi nombre es Jose Aular y actualmente me desempeño como administrativo\. Mis expectativas para la materia son aprender a utilizar herramientas de ciencia de datos e IA para integrar a modelos prácticos para aplicarlos en proyectos reales, potenciar mi profesion y actualizarme en el mercado; con la posibilidad de migrar al sector IT\.

# %%
print("Mi primer notebook en Deepnote")
# Out:
# Mi primer notebook en Deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2702a4ff-d1c1-4fa6-b36d-0e6eb3f456fc' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
